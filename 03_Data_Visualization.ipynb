# %% [markdown]
# # Data Visualization with Matplotlib and Seaborn
#
# This notebook covers data visualization techniques using Matplotlib and Seaborn.

# %% [markdown]
# ### Introduction to Matplotlib
# Matplotlib is a versatile plotting library in Python.

# %%
# Importing Matplotlib
import matplotlib.pyplot as plt

# Example: Plot temperature data
temps = [22.5, 25.3, 20.8, 18.6, 30.0]
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

plt.plot(days, temps)
plt.title('Daily Temperatures')
plt.xlabel('Day')
plt.ylabel('Temperature (°C)')
plt.show()

# %% [markdown]
# ### Introduction to Seaborn
# Seaborn provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
# Importing Seaborn
import seaborn as sns

# Example: Create a boxplot of temperatures
sns.boxplot(temps)
plt.title('Temperature Distribution')
plt.show()

# %% [markdown]
# ## Hands-on Exercise
# Visualize a weather dataset using different plot types (e.g., line plot, box plot, heatmap).
